# %% [markdown]
# # Tempe Image Classification from Scraping Image to Model Deployment

# %% [markdown]
# Final Project for AI Mastery Bootcamp
# Danang Yudhatama
# ID: REA95EWY
#
# In this Capstone Project, I try to build a Tempe Image Classifier from image collection, data processing, model training and serving.

# %%
# %pip install bing-image-downloader
# %pip install torch
# %pip install pillow
# %pip install requests

# %%
# %pip install torchvision
# %pip install matplotlib
# Out:
# Requirement already satisfied: torchvision in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (0.17.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.2.1 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (4.10.0)
# Requirement already satisfied: sympy in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (1.12)
# Requirement already satisfied: networkx in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from torch==2.2.1->torchvision) (2024.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from jinja2->torch==2.2.1->torchvision) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from sympy->torch==2.2.1->torchvision) (1.3.0)
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.50.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from matplotlib) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.3-cp312-cp312-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.50.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.50.0 kiwisolver-1.4.5 matplotlib-3.8.3 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# %pip install tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Collecting tqdm
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\acer\final_project_ai_engineer_sa\final-project\lib\site-packages (from tqdm) (0.4.6)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader

#create a list of tempe queries, which will be sraped
tempe_queries = ['baked tempeh',
                 'gorengan tempe,',
                 'kering tempe',
                 'mendoan',
                 'oseng-oseng tempe',
                 'semur tempe',
                 'tempe bacem',
                 'tempe bakar',
                 'tempe goreng',
                 'tempe mentah',
                 'tempeh']

for query in tempe_queries:
    downloader.download(query, limit=100, output_dir='test_dataset_tempe')

#create a list of not_tempe queries, which will be sraped
not_tempe_queries = ['ayam bakar',
                    'ayam goreng',
                    'nasi goreng',
                    'oseng-oseng',
                    'oseng-oseng bihun',
                    'oseng-oseng mie',
                    'oseng-oseng tahu',
                    'tahu']

for query in not_tempe_queries:
    downloader.download(query, limit=100, output_dir='dataset_not_tempe')
# Out:
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\baked tempeh
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.runningtothekitchen.com/wp-content/uploads/2021/01/Marinated-tempeh-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh2.jpg
# [Error]Invalid image, not saving https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh2.jpg
#
# [!] Issue getting: https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh2.jpg
# [!] Error:: Invalid image, not saving https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh2.jpg
#
# [%] Downloading Image #2 from https://frommybowl.com/wp-content/uploads/2019/09/3_Ingredient_Crispy_Tempeh_Vegan_GlutenFree_FromMyBowl-6-683x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.forkandbeans.com/wp-content/uploads/2013/02/buffalo2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.theliveinkitchen.com/wp-content/uploads/2020/10/14113650/Thanksgiving-Baked-Tempeh-The-Live-In-Kitchen-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.peacefuldumpling.com/wp-content/uploads/2017/10/apple-butter-baked-tempeh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/736x/99/0b/0d/990b0d7b4ba8e9b34cded14f34600ae3--baked-tempeh-savory-herb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.runningtothekitchen.com/wp-content/uploads/2021/01/Marinated-tempeh-9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://minimalistbaker.com/wp-content/uploads/2016/12/7-Ingredient-Marinated-Baked-PEANUT-TEMPEH-Salty-sweet-spicy-and-perfect-for-topping-salads-and-more-vegan-glutenfree-tempeh-recipe-minimalistbaker-dinner.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://minimalistbaker.com/wp-content/uploads/2016/12/7-Ingredient-Marinated-Baked-PEANUT-TEMPEH-Salty-sweet-spicy-and-perfect-for-topping-salads-and-more-vegan-glutenfree-tempeh-recipe.jpg
# [Error]Invalid image, not saving https://minimalistbaker.com/wp-content/uploads/2016/12/7-Ingredient-Marinated-Baked-PEANUT-TEMPEH-Salty-sweet-spicy-and-perfect-for-topping-salads-and-more-vegan-glutenfree-tempeh-recipe.jpg
#
# [!] Issue getting: https://minimalistbaker.com/wp-content/uploads/2016/12/7-Ingredient-Marinated-Baked-PEANUT-TEMPEH-Salty-sweet-spicy-and-perfect-for-topping-salads-and-more-vegan-glutenfree-tempeh-recipe.jpg
# [!] Error:: Invalid image, not saving https://minimalistbaker.com/wp-content/uploads/2016/12/7-Ingredient-Marinated-Baked-PEANUT-TEMPEH-Salty-sweet-spicy-and-perfect-for-topping-salads-and-more-vegan-glutenfree-tempeh-recipe.jpg
#
# [%] Downloading Image #9 from https://www.peacefuldumpling.com/wp-content/uploads/2017/10/vegan-apple-butter-baked-tempeh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://i.pinimg.com/originals/25/94/35/259435ccafd0648d2bd70a5f06221c69.png
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://fthmb.tqn.com/zrm2l_b5VbdcnnC9NiUUr8JrKSk=/1895x1407/filters:fill(auto,1)/Lauren-Krohn-tempeh-582072e03df78cc2e82d8bdd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://frommybowl.com/wp-content/uploads/2019/09/3_Ingredient_Crispy_Tempeh_Vegan_GlutenFree_FromMyBowl-4-683x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://watchlearneat.com/wp-content/uploads/2019/11/maple-dijon-baked-tempeh-sq-scaled-e1574740450842.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://frommybowl.com/wp-content/uploads/2019/09/3_Ingredient_Crispy_Tempeh_Vegan_GlutenFree_FromMyBowl-11-1170x1755.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.yummymummykitchen.com/wp-content/uploads/2018/03/490a5-bbq-tempeh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://veggieprimer.com/wp-content/uploads/2016/07/Baked-BBQ-Tempeh_4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://imagesvc.meredithcorp.io/v3/mm/image?url=https:%2F%2Fimages.media-allrecipes.com%2Fuserphotos%2F1796627.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://veganuary.com/wp-content/uploads/2016/07/Sesame-Crusted-Tempeh-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://www.runningtothekitchen.com/wp-content/uploads/2021/01/Marinated-tempeh-5-614x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://4.bp.blogspot.com/-vqNvbnokiXw/WOaGVsVZcOI/AAAAAAAA6lY/qFZBhygaWgIla_92sO9Dti-098CN4wOoQCLcB/s1600/BBQ-baked-tempeh-recipe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh3.jpg
# [Error]Invalid image, not saving https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh3.jpg
#
# [!] Issue getting: https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh3.jpg
# [!] Error:: Invalid image, not saving https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempeh3.jpg
#
# [%] Downloading Image #21 from https://i.pinimg.com/originals/c4/3b/65/c43b656b17c23fa970212642b13e4697.png
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://frommybowl.com/wp-content/uploads/2019/09/3_Ingredient_Crispy_Tempeh_Vegan_GlutenFree_FromMyBowl-10-1170x780.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://i.pinimg.com/736x/99/72/7c/99727c91d6d7b50cfbd81622b5aae12c--baked-tempeh-work-week.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://frommybowl.com/wp-content/uploads/2019/09/3_Ingredient_Crispy_Tempeh_Vegan_GlutenFree_FromMyBowl.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://www.eatingbirdfood.com/wp-content/uploads/2018/04/bbq-tempeh-chips-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://www.thefullhelping.com/wp-content/uploads/2016/01/Lemon-pepper-tempeh-cubes-2-1024x1536.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.erinliveswhole.com/wp-content/uploads/2019/03/bbq-baked-tempeh-4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://thymeandlove.com/wp-content/uploads/2021/05/tempeh-recipe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempehPrep4.jpg
# [!] Issue getting: https://dishingouthealth.com/wp-content/uploads/2020/04/BakedTempehPrep4.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #29 from https://1.bp.blogspot.com/-I_t6Ouh-CaU/WOaGVTtRy1I/AAAAAAAA6lU/MdscfvaDzgIU-RJa74LX8I0MJGSM6y6kwCLcB/s1600/BBQ-tempeh-recipe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://thymeandlove.com/wp-content/uploads/2015/06/DSC_0745-ed-post.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://i.pinimg.com/originals/c9/b0/02/c9b00202b07cb8a71b550e65ac0a596d.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #32 from https://www.runningtothekitchen.com/wp-content/uploads/2021/01/Marinated-tempeh-6-600x777.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #33 from https://cdn.theliveinkitchen.com/wp-content/uploads/2020/10/14113715/Thanksgiving-Baked-Tempeh-The-Live-In-Kitchen-5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://www.peacefuldumpling.com/wp-content/uploads/2017/10/apple-butter-baked-tempeh-vegan-700x1050.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 34 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\gorengan tempe,
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://img-global.cpcdn.com/recipes/65879bf00a7b2acd/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img-global.cpcdn.com/recipes/f9e5223fce9440f1/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/z/gorengan-tempe-indonesian-fried-tempe-snack-served-sambal-chili-sauce-chilli-pepper-gorengan-tempe-indonesian-fried-178090004.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.masakapahariini.com/wp-content/uploads/2022/09/resep-tempe-goreng-tepung-pedas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn-2.tstatic.net/tribunnews/foto/bank/images/cara-bikin-tempe-goreng-tepung-tidak-keras-walau-dingin.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-Z_ictdel160/WWl6-Ma8zCI/AAAAAAAAACw/fIWP6V9mbWEqlRA1hME6XfSi3vYRP9pmQCLcBGAs/s1600/t.png
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.halobdg.com/wp-content/uploads/2021/04/Tempe-Goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://img-global.cpcdn.com/recipes/6c9faa37e9c2fc41/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://www.indoindians.com/wp-content/uploads/2017/06/tempe-goreng.jpg
# [!] Issue getting: https://www.indoindians.com/wp-content/uploads/2017/06/tempe-goreng.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #9 from https://media.suara.com/pictures/970x544/2021/01/27/93120-tempe-dan-tahu-goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://3.bp.blogspot.com/-Iz19I9UQDZ0/U64c34Y6CYI/AAAAAAAADqI/EEyuQnYFwF8/s1600/IMG_1522.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://www.honestdocs.id/system/blog_articles/main_hero_images/000/003/396/original/bahaya_makan_gorengan_untuk_buka_puasa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://i.pinimg.com/originals/49/9b/38/499b384e8e24514af671f8e457612d15.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://resepmasakandapurarie.com/wp-content/uploads/2015/03/Resep-tempe-mendoan-tempe-goreng-tepung.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://i.pinimg.com/originals/b3/f3/c9/b3f3c96a57abd01786efc21d748c6e28.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://cdn.idntimes.com/content-images/community/2019/05/53767113-552504335237913-5525870468519634609-n-a79c0b0c6bac4510182cdb39b40b3c3a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://3.bp.blogspot.com/-a2azo2BKZ2E/UhWgmq1hEvI/AAAAAAAAAFo/zJnndd1K5Fc/s1600/gorengan-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://beritajatim.com/wp-content/uploads/2022/10/WhatsApp-Image-2022-10-29-at-09.31.32.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://4.bp.blogspot.com/-Dj01EcyKku4/VdYBT2n5IFI/AAAAAAAACVU/xgh5q7-7QrI/s640/tempe-goreng-kremes-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://static1.bigstockphoto.com/4/8/3/large1500/384798230.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://www.islampos.com/wp-content/uploads/2018/12/Tempe-Goreng.png
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://goodlife.id/wp-content/uploads/2020/07/gorengan_aneka.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://img-global.cpcdn.com/recipes/9f46031ec828a908/1502x1064cq70/tempe-mendoan-garing-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://cdn.idntimes.com/content-images/community/2020/02/intankarinaijo-bkuuxj9aktv-bf11791b838d5ec078ff9c39b9fcda74.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://i.ytimg.com/vi/6bov5HzB6Z8/hqdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://jeda.id/files/2019/07/26-gorengan-1024x683.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://2.bp.blogspot.com/-AKprvm_9UL8/Upqcw-PCImI/AAAAAAAAEWQ/IxF3Oy5HGp0/s1600/gorengan+tips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://wiratech.co.id/wp-content/uploads/2020/01/Gorengan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://static2.bigstockphoto.com/7/6/3/large1500/367279381.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://www.jatik.com/wp-content/uploads/2015/06/gorengan_gurih.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://i.ytimg.com/vi/oWjdbJ27jus/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://www.cookmeindonesian.com/wp-content/uploads/2020/09/tempe-goreng4-1140x1489.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from http://2.bp.blogspot.com/_zFJtHG2GEmo/TSHJH9yMy1I/AAAAAAAAAE0/N6eVsOTfbgg/s1600/tempe+goreng.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://img-global.cpcdn.com/003_recipes/5cd0f77d8fb3321d/751x532cq70/tempe-goreng-garing-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://www.peko-peko.fr/recettes/tempe-mendoan/second.jpg_large.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #35 from https://png.pngtree.com/png-clipart/20211117/ourmid/pngtree-tempe-goreng-png-image_4034519.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #36 from https://img-global.cpcdn.com/recipes/f9e5223fce9440f1/751x532cq70/mendoan-gorengan-tempe-tempe-glepung-tempe-tepung-foto-resep-utama.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #37 from https://img-global.cpcdn.com/recipes/98dad1dccb9aed27/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://thumbs.dreamstime.com/z/gorengan-indonesian-traditional-street-food-snacks-pisang-goreng-bakwan-tempe-served-sambal-chili-sauce-chilli-178092732.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #39 from https://i.ytimg.com/vi/u64tzxFVfk4/hqdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #40 from https://img-global.cpcdn.com/recipes/510dff683f849b9d/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #41 from https://3.bp.blogspot.com/-RO4FVEtjk7k/T4z245B2IVI/AAAAAAAAAkg/kYGH3alHwuA/s1600/Kripik+Tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://mojok.co/terminal/wp-content/uploads/2020/06/kasta-gorengan-risol-mendoan-pisang-goreng-tempe-goreng-bakwan-mojok.co_.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #43 from https://1.bp.blogspot.com/-gpgfZa3FNdo/XwgcktajSbI/AAAAAAAAEAM/fmonRKYmTCg6Oox6ohPxOTaW1QOmUZ5yACLcBGAsYHQ/s2048/IMG_20200708_104725.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #44 from https://img-global.cpcdn.com/003_recipes/6c9faa37e9c2fc41/751x532cq70/tempe-goreng-tepung-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://www.indoindians.com/wp-content/uploads/2017/06/tempe-goreng-768x512.jpg
# [!] Issue getting: https://www.indoindians.com/wp-content/uploads/2017/06/tempe-goreng-768x512.jpg
# [!] Error:: HTTP Error 404: Not Found
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #45 from https://img-global.cpcdn.com/recipes/5383ed7a1fb0315e/1502x1064cq70/tahu-tempe-goreng-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from http://2.bp.blogspot.com/-sfG5SDxHQZA/VGd4yyBWzLI/AAAAAAAAAJE/Yu0-G5hqX-M/s1600/goreng%2Btempe.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #47 from https://i.pinimg.com/originals/a2/db/55/a2db55f027a5e69f0c12733c8f9e0ed6.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #48 from https://i.ytimg.com/vi/EclnJMRqQko/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #49 from https://media.suara.com/pictures/653x366/2021/01/27/93120-tempe-dan-tahu-goreng.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #50 from https://d324bm9stwnv8c.cloudfront.net/artikel/20180821080543.012-704013352.png
# [%] File Downloaded !
#
# [%] Downloading Image #51 from https://media.suara.com/pictures/970x544/2018/10/24/12158-tempe-dan-tahu-goreng.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
# [%] Downloading Image #52 from https://img-global.cpcdn.com/recipes/81ce7b57863374de/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #53 from https://i.ytimg.com/vi/FoGduNkTpH8/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #54 from https://images.genpi.co/uploads/arsip/watermark/2022/02/21/minyak-goreng-tahu-dan-tempe-mulai-langka-tukang-gorengan-oslv.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #55 from https://cdn.idntimes.com/content-images/post/20190806/64914423-350270569014027-721314326503957408-n-0c35c6bb6f210d4ab6736d3d270ef463.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #56 from https://1.bp.blogspot.com/-Sl8uq0vQel8/VwNBuFGUjlI/AAAAAAAAAIw/jqGWj8GgMToE9tIlonQ1A8P8gt-GPnShw/s1600/Resep%2BTempe%2BGoreng%2BKremes%2Byang%2BRenyah%252C%2BMurah%252C%2BMudah%2Bdan%2BLezat%252C%2Bresep%2Btempe%252C%2Btempe%2Bgoreng%252C%2Bmasakan%2Btempe%252C%2Btempe%2Bmurah%252C%2Bgorengan%252C%2Bgoreng%2Btempe.%2Btempe%2Bkremes%252C%2Bresep%2Btempe%252C%2Bmembuat%2Btempe%2Bgoreng%252C%2Btempe%2Bgore.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
# [%] Downloading Image #57 from https://cdn.idntimes.com/content-images/post/20210625/148913489-448034686320900-2132947067757663738-n-8c2933091cb7301000f5b60623af108a.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 25
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 57 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\kering tempe
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://wilandwayanskitchen.com/wp-content/uploads/2013/06/kering-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-OZ3Ezich7rk/XxVSvMVb1kI/AAAAAAAAfEo/0kz8xRGpz9gcXm9G5ToDd5uNKIpy6OnrACLcBGAsYHQ/s1073/Kering%2BTempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://portalmadura.com/wp-content/uploads/2019/05/Resep-Membuat-Kering-Tempe-Kecap-Enak-Gurih.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://1.bp.blogspot.com/--BaO7dTFWEE/T3UecvKxj2I/AAAAAAAAAnc/hkwcCvJ6ZBA/s1600/kering+tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://satujam.com/wp-content/uploads/2015/12/Kering-Tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i2.wp.com/resepkoki.id/wp-content/uploads/2016/11/Resep-Tempe-Kering-e1506050982466.jpg?fit=1156%2C1300&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://file.santicatering.com/kering_tempe_teri_kacang-d8951-3036_281.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://1.bp.blogspot.com/-jAPBD_NTCEk/U4hxxDHF9NI/AAAAAAAACV0/-cq2LLkrKu0/s1600/Menu+Nasi+Tumpeng+Murah+di+Surabaya,+kering+tempe+(2).JPG
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://4.bp.blogspot.com/-QEXl6lMba3c/Uo3h_plTBjI/AAAAAAAAAho/tbspemAywiI/s1600/kering_tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://img-global.cpcdn.com/recipes/bbb90adcd1740a39/680x482cq70/kering-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://img.okezone.com/content/2020/04/11/298/2197746/cara-membuat-kering-tempe-manis-seperti-buatan-ibu-CuY7tUknV6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://4.bp.blogspot.com/_-xdGfmndoVM/THoPApG5tTI/AAAAAAAAAAU/Rrp1jk9IrIo/s1600/kering+tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://3.bp.blogspot.com/-gBXsXUWEOI0/T3Uf_i2YVFI/AAAAAAAAAnk/5FQC3ayc2cA/s1600/kering+tempe+2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://1.bp.blogspot.com/-giWt_YOP3hY/UlVObqHaX8I/AAAAAAAAHEo/AH58oZqtlaY/s1600/Kering+Tempe+new+2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.resepistimewa.com/wp-content/uploads/tempe-orek-kering.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://3.bp.blogspot.com/-El-W3CH2HAg/UBzBXneqBmI/AAAAAAAAAXw/22RYybODzaY/s1600/Kering-Tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://1.bp.blogspot.com/-qVj9wEWfHK4/YBzp4dd27XI/AAAAAAAAfu0/AbGVIGeDWo4HOGSjN4z5ReQJwNBkU_aGQCLcBGAsYHQ/s1178/Kering%2BTempe%2B-%2BNasi%2BBerkat%2B.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://www.piknikdong.com/wp-content/uploads/2020/07/68895415_518244368980544_3062222542747230081_n.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://www.masakapahariini.com/wp-content/uploads/2020/05/kering-tempe-teri-7_edited.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://4.bp.blogspot.com/-TXMXtQN9CMM/T54tgYheU_I/AAAAAAAAIto/g15OI3dAWi4/s1600/KERING+TEMPE.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://img-global.cpcdn.com/003_recipes/1207a2055fe080f8/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://i.ytimg.com/vi/xXt8pKpQdKw/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://ncc-indonesia.com/wp-content/uploads/2013/12/Kering-Tempe-ncc-620x300.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://img-global.cpcdn.com/recipes/d0fed497f9c67c6a/751x532cq70/kering-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://a4.pbase.com/g1/76/410576/2/108106628.BrWoL8dG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://cdn-image.hipwee.com/wp-content/uploads/2021/04/hipwee-kering-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from http://1.bp.blogspot.com/-giWt_YOP3hY/UlVObqHaX8I/AAAAAAAAHEo/AH58oZqtlaY/w1200-h630-p-k-no-nu/Kering+Tempe+new+2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://img-global.cpcdn.com/003_recipes/d1ff071e3e570082/751x532cq70/kering-tempe-pedas-manis-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://img-global.cpcdn.com/recipes/751cbf2cad9bdf7a/680x482cq70/kering-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://img-global.cpcdn.com/recipes/1cc3001a5c78e888/680x482cq70/kering-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from http://3.bp.blogspot.com/-4B_CnQgZmlU/UfDlfwfJc-I/AAAAAAAAB-E/7ripw6W5cWw/s1600/Kering+Tempe+Teri.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://img-global.cpcdn.com/recipes/2e2ad858f5f795a6/680x482cq70/kering-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from http://3.bp.blogspot.com/-Y_KWbuyDLNU/UYdeVuMWdfI/AAAAAAAAFh0/lKTcGpDtb6Y/s1600/kering+tempe+teri.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://img-global.cpcdn.com/recipes/a4d540cde8c24e69/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from http://www.mithra.si/wp/wp-content/uploads/2013/04/DSC08934.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #36 from http://4.bp.blogspot.com/-fX-XvtrS6tE/URpecGI6BvI/AAAAAAAABDE/6BWi5gdGUyw/s1600/tempe4.JPG
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #37 from https://3.bp.blogspot.com/-aI2AhWY6GZI/UsVoRU9_-TI/AAAAAAAAftU/EiV-Y9Z6vz0/s1600/Resep-Kering+Tempe+%2528Sweet+%2526+Spicy+Deep+Fried+Tempeh%2529.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://awsimages.detik.net.id/community/media/visual/2020/03/18/e430273c-5134-4f07-8871-7442ab2b841e_11.jpeg?w=700&amp;q=90
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://d1uz88p17r663j.cloudfront.net/resized/482e66858ca1bc1e8b003c89f4b5aa29_Maggi-Elevate---10_944_531.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from http://4.bp.blogspot.com/_-xdGfmndoVM/THoPApG5tTI/AAAAAAAAAAU/Rrp1jk9IrIo/s1600/kering+tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://cdn.idntimes.com/content-images/post/20190510/dapurmamacicia-a395e8ae9e723434cfb1b955e91f2d30.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://thegorbalsla.com/wp-content/uploads/2019/05/Resep-Kering-Tempe-Campur-Mie.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from http://wilandwayanskitchen.com/wp-content/uploads/2013/06/kering-tempe-ingredients.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from http://1.bp.blogspot.com/-D-iclMEWc58/T36TGa9PpEI/AAAAAAAAAQk/vWG04fzzp88/s1600/rsz_1kering_tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://i1.wp.com/resepkoki.id/wp-content/uploads/2017/08/Resep-Kering-kentang-tempe-pedas.jpg?fit=2322%2C2322&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://4.bp.blogspot.com/-4KPf7PacF40/VsayEonFGII/AAAAAAAADm0/o_sPYPd97vU/s1600/keringtempe2.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://cdn1-production-images-kly.akamaized.net/atZ18CHZu3gpA_1mqbvfkKIWkWo=/621x0:1555x1246/680x906/filters:quality(75):strip_icc():format(jpeg)/kly-media-production/medias/2705096/original/095507500_1547616035-shutterstock_441430000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://www.langsungenak.com/wp-content/uploads/2017/09/Kering-Tempe-by-Yunda-Yun.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 48 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\mendoan
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://2.bp.blogspot.com/-phpCnKPagaU/U1HvC_j0phI/AAAAAAAAABM/0rY8Qx116sk/s1600/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://lh5.googleusercontent.com/proxy/1pBpk1ifewSElC_vQ0mSX3Tn6nodCJUIOIAEcJJTa1Sk1RgLQG6PiV4rfqn8c-TM9RAlmtRWWLomr_FlJuUWlLb5DNerYhQ-lf9n24pj6gqf6gb6h4gsSDPxkprzg11r=w1200-h630-p-k-no-nu
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://d12man5gwydfvl.cloudfront.net/wp-content/uploads/2020/04/shutterstock_657671500-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://2.bp.blogspot.com/-LF5WRsS2vfA/TenOzdE1w6I/AAAAAAAAAmA/fdv3YUPgxDc/w1200-h630-p-k-no-nu/tempe-mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://1.bp.blogspot.com/-RnKZB6478CQ/X1yqZj-oUKI/AAAAAAAAfa4/wyp6WbTOrkEaoqWHKi5BElf4WWZw5CqsQCLcBGAsYHQ/s1122/Mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://2.bp.blogspot.com/_qx49oIT4yjM/TSZqb-HxZfI/AAAAAAAAALk/0GjAAsb_8lY/s1600/Pecel+%2526+mendoan.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://3.bp.blogspot.com/-5pyEofI3Tsk/UMgd86X0G-I/AAAAAAAABWc/5p_5i35wsnw/s1600/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://2.bp.blogspot.com/-fkc08zYjP94/T6cCHhe1UiI/AAAAAAAAAl0/rQEiPgY9oYw/s1600/tempe+mendoan.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://4.bp.blogspot.com/_K-niRUpV1dg/TDV4nE90tgI/AAAAAAAAAWw/7dK4l5op2z4/s1600/mendoan2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://2.bp.blogspot.com/_AeRo3r1oZ-E/TLyQH26QcjI/AAAAAAAACXQ/B40OeyhcXxo/s1600/mendoan+2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://1.bp.blogspot.com/-Yx5IO7SoQf8/YL90awtJy0I/AAAAAAAAf9Q/gefUkgBwKMIAfqexRJKR1AoUtkAk9HYiwCLcBGAsYHQ/s1352/198529037_291043326045930_5087145767493958337_n.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://2.bp.blogspot.com/-4uZ2O7yTn-M/V6CeRKqgSKI/AAAAAAAAAhE/RgkpaX7YYgoiNrDM1ukfuWkgYu084VPFgCLcB/w1200-h630-p-k-no-nu/mendoan-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.creativefabrica.com/wp-content/uploads/2020/01/03/Mendoan-Fonts-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://1.bp.blogspot.com/_AeRo3r1oZ-E/TLyQHp7MJTI/AAAAAAAACXI/QnIwx9xSQ7M/s1600/mendoan+1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://i0.wp.com/resepkoki.id/wp-content/uploads/2017/08/mendoan-brilio.jpg?fit=1000%2C709&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://images.solopos.com/2019/12/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://www.djkn.kemenkeu.go.id/files/images/2021/06/mendoan.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://3.bp.blogspot.com/-gLoNnDIyVMw/WNowaqc3hzI/AAAAAAAABnQ/AJYbohMMjFYf-3NLySI9HIlMMXlOlBvXQCLcB/s1600/%252820%2529%2Bmendoan%2Bbrokoli.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://www.goodnewsfromindonesia.id/wp-content/uploads/images/source/wihdiluthfi/20200403main-photo-1528088030883-x.png
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://i.scdn.co/image/9751a28b8ccdae1e58db66c88c2305f8d021bd51
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://graphicex.com/uploads/posts/2020-01/1578962844_OHuawBw.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://kontenstore.com/wp-content/uploads/2022/02/Tempe-mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://lh3.googleusercontent.com/-j7lHs3EExE0/V2rhaJnv87I/AAAAAAAABs8/TwWk3AxIwlo/s1600/IMG-20160623-WA0000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://png.pngtree.com/png-clipart/20220612/original/pngtree-delicious-tempe-mendoan-from-indonesia-png-image_7966447.png
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://2.bp.blogspot.com/-7XiIYR8sZKI/VNCCbI0tj1I/AAAAAAAAQHg/Uwk0RJqqodk/s1600/Mendoan%2Bimut%2B4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://2.bp.blogspot.com/-8QNr2tJRbCI/VE-WFg63YFI/AAAAAAAABPI/h-KW4Dlfmks/w1200-h630-p-k-no-nu/Resep-Tempe-Mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://thedailyroar.com/wp-content/uploads/2013/05/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://1.bp.blogspot.com/_5aOGQe3_17g/S_kl1LPtI7I/AAAAAAAAACg/WQRD3CNYz50/s1600/mendoan2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://diskon.com/images/1386302246__20131115_170033.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://media.suara.com/pictures/970x544/2019/06/09/91902-tempe-mendoan-banyumas-suaracomteguh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from http://4.bp.blogspot.com/_y3NXELsL-ro/SlMrpSrN-jI/AAAAAAAAAOA/Aq_h-Ny7G5g/w1200-h630-p-k-no-nu/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://phinemo.com/wp-content/uploads/2018/09/41040594_927491404113820_6899303954426933340_n.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://static.republika.co.id/uploads/images/inpicture_slide/penjual-mendoan-tengah-menggoreng-mendoan-jumbo-di-sentra-kuliner_220314213928-950.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://katabunda.com/wp-content/uploads/2016/06/mendoan-1068x801.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://2.bp.blogspot.com/-8hZ2mTpvs4A/VphlpYbRv0I/AAAAAAAAAiI/b9gAW3z9jCk/s1600/Mendoan%2BEdit.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #36 from https://1.bp.blogspot.com/-xLd0ZhB9iU0/XhkarHoueOI/AAAAAAAAQpI/WLnVdoCdS-08C7BuhbT0slNKqdRx3_4lwCLcBGAsYHQ/w1200-h630-p-k-no-nu/tempe-mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://2.bp.blogspot.com/-V2BcFlhFkF4/T-B4ywgtHsI/AAAAAAAAAI0/uBqbWnZKge4/s1600/mendoan+label.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #38 from http://divaboga.com/wp-content/uploads/2020/07/Tepung-Mendoan.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #39 from https://1.bp.blogspot.com/-2il69aA6SfQ/XVWG2XllpbI/AAAAAAAAAHg/371e2tIRdHIq-408JFvA-FpDnUCnpZ9uQCLcBGAs/s1600/Mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #40 from https://1.bp.blogspot.com/-yyQBnrWYUPk/YL90aueniWI/AAAAAAAAf9M/OQ25ImiwgvcGXqqk63m4wwKm1DK_mEi5ACLcBGAsYHQ/s1350/198910858_173158954754290_7429424468979556378_n.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from http://1.bp.blogspot.com/-SeHEGVlOeUU/VNCCaAUSmZI/AAAAAAAAQHU/dqUKEk4pyNo/s1600/Mendoan%2Bimut%2B2.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #42 from https://i.ytimg.com/vi/iaP5lvz_iGc/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #43 from https://yt3.ggpht.com/a/AATXAJwSku7yud7medbb7qZXWCiUR6j5Kb3FbKoVKQ=s900-c-k-c0xffffffff-no-rj-mo
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #44 from https://3.bp.blogspot.com/_JXE1J03CwYI/SfYySW_dMuI/AAAAAAAAAb8/UN-ewB0bFkU/s320/mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #45 from http://1.bp.blogspot.com/_K-niRUpV1dg/TDV5bPf5FtI/AAAAAAAAAW4/5mRpjJsX2T4/s1600/mendoan1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #46 from http://dirottsaha.com/wp-content/uploads/2015/11/mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #47 from https://is5-ssl.mzstatic.com/image/thumb/Podcasts125/v4/ba/e6/79/bae6796a-21cc-f2bf-ac38-f1656d4adab4/mza_15247338286471753521.jpg/1200x630wp.png
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://3.bp.blogspot.com/-defpH-46qbo/VA7bWXTUIeI/AAAAAAAABhs/jgUVEV8FH-Q/s1600/Mendoan.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://1.bp.blogspot.com/-ukvCqQIQ0eI/X13DdRvSipI/AAAAAAAAXz8/qfnS5Lcz1Fos-uU7MJPKRYNGBv30mWu6ACLcBGAsYHQ/s2048/Mendoan%2BSemarang%2Bvs%2BMendoan%2BPurwokerto.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #50 from https://i.ytimg.com/vi/HbGehk4skPY/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #51 from https://1.bp.blogspot.com/-DvpGCZtPi1o/VTcj148Q2TI/AAAAAAAAACM/8wNoB0imbWI/s1600/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #52 from https://1.bp.blogspot.com/-RnKZB6478CQ/X1yqZj-oUKI/AAAAAAAAfa4/wyp6WbTOrkEaoqWHKi5BElf4WWZw5CqsQCLcBGAsYHQ/w378-h400/Mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://keluyuran.com/wp-content/uploads/2020/08/Mendoan-Copy.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #54 from https://4.bp.blogspot.com/-s64QOaUDdN4/T_U87prPJZI/AAAAAAAAA_Y/im9X9nhlMUU/s1600/mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #55 from https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=2259107954312405
# [Error]Invalid image, not saving https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=2259107954312405
#
# [!] Issue getting: https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=2259107954312405
# [!] Error:: Invalid image, not saving https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=2259107954312405
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #55 from https://3.bp.blogspot.com/-9DRuSuGG0So/WFD9MhlrVWI/AAAAAAAABgg/n0PhoEn8upwdTTpNZOrhINHCzNvg4TtRACLcB/s1600/mendoan.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #56 from https://1.bp.blogspot.com/_5gaieb2T31k/Rx_pAW8G9QI/AAAAAAAAABQ/ME52UZjH4r0/s320/mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from http://3.bp.blogspot.com/-hW9tAoI5KjQ/Ul36ab_XJtI/AAAAAAAAAY4/U0xS19m-jUM/s1600/mendoanbms.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from http://2.bp.blogspot.com/-056QG8c5TcU/TyT1p-5_iSI/AAAAAAAAAPw/NHehsuYHbmo/s1600/adonan+mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #59 from https://i.ytimg.com/vi/2Tdu9u-VWQ4/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from https://i.ytimg.com/vi/OUvGZ5dujvM/hqdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://2.bp.blogspot.com/-V8bJTVwzDTw/U8TsMwzjp8I/AAAAAAAAH4Q/EpmwLUIUiSU/s1600/mendoan.JPG
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
# [%] Downloading Image #62 from https://4.bp.blogspot.com/-9CCXwZhzoyg/T8OrAKcC7SI/AAAAAAAAAD8/T0KDrKWW3Fc/s320/mendoan.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 27
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 62 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\oseng-oseng tempe
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.cookmeindonesian.com/wp-content/uploads/2020/04/oseng-oseng-tempe1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i0.wp.com/resepkoki.id/wp-content/uploads/2020/03/Resep-Oseng-Tempe-Cabe-Ijo.jpg?fit=1079%2C1118&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn-brilio-net.akamaized.net/news/2021/02/24/201033/1414643-1000xauto-resep-oseng-oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://sweetrip.id/wp-content/uploads/2022/07/oseng-tempe-pete-2-1024x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.masakapahariini.com/wp-content/uploads/2018/04/resep_oseng_tempe_MAHI.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn-brilio-net.akamaized.net/news/2021/02/24/201033/1414642-1000xauto-resep-oseng-oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://img-global.cpcdn.com/recipes/bff4311e66c10527/751x532cq70/oseng-oseng-tempe-stir-fried-tempe-vegan-recipe-main-photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://cdn-brilio-net.akamaized.net/news/2021/02/24/201033/1414641-1000xauto-resep-oseng-oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://img-global.cpcdn.com/recipes/bb3a1fae030289bd/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://2.bp.blogspot.com/-8DBXTGVJ_TU/Tk1V1yBkP8I/AAAAAAAAAQE/qDu_VBvlEEA/s1600/tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://3.bp.blogspot.com/-LzEVw2FgM44/T19L5llWTlI/AAAAAAAAAzs/hpuEZCmkkmo/s1600/IMG_0451.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://cdn-brilio-net.akamaized.net/news/2021/02/24/201033/1414636-1000xauto-resep-oseng-oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://4.bp.blogspot.com/-lNTqwJkYFm8/UMXXwP-Ye5I/AAAAAAAACDs/s33NMncvkjE/s1600/oseng+tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://farm5.static.flickr.com/4076/4862772180_8d52dd8312_z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://assets.resepedia.id/assets/images/2020/07/1673457568918279-oseng-tempe-lombok-ijo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://img-global.cpcdn.com/recipes/e7eac3a0ad33576d/680x482cq70/oseng-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://img-global.cpcdn.com/recipes/1da92605d4a22be5/680x482cq70/oseng-oseng-tempe-teri-medan-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://www.dapurkobe.co.id/wp-content/uploads/oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://i.pinimg.com/originals/62/b4/d0/62b4d0d4845d90258dac4664dc677b09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://img-global.cpcdn.com/recipes/1f96daadda9cc3ee/680x482cq70/oseng-oseng-tempe-tempe-orek-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://2.bp.blogspot.com/-uxTMBXlHhEs/WbtAzeMC-NI/AAAAAAAAFqg/U9ZUMF0eR3sUZ_lHV_8koFTMoh-qsc-hwCLcBGAs/s1600/Oseng%2BTempe%2BBaru.png
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://2.bp.blogspot.com/-8DBXTGVJ_TU/Tk1V1yBkP8I/AAAAAAAAAQE/qDu_VBvlEEA/w1200-h630-p-k-no-nu/tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://img.okezone.com/content/2015/08/20/298/1199656/resep-oseng-oseng-kacang-panjang-tempe-daGOBaMvHZ.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://1.bp.blogspot.com/-0r2NVY3Q3zI/SDG-kCDoAZI/AAAAAAAACUo/j-ZaohabaRg/s1600/tempeh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://img-global.cpcdn.com/recipes/739a13028c9ff978/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://cdn-brilio-net.akamaized.net/news/2021/02/24/201033/1414637-1000xauto-resep-oseng-oseng-tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://1.bp.blogspot.com/-F-FDI-wV2Pg/Ur5ggu_jhRI/AAAAAAAAEs4/DB5N7Y9D_pk/s1600/Foto0607.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://img-global.cpcdn.com/003_recipes/dff9604951323d48/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://img-global.cpcdn.com/recipes/5104dadd8b2c8bde/751x532cq70/oseng-oseng-tempe-kacang-panjang-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://img-global.cpcdn.com/recipes/22c4a623efe97a95/751x532cq70/oseng-tempe-kecap-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://live.staticflickr.com/3052/2550291481_ec58665df8_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://img-global.cpcdn.com/003_recipes/309c482032a848b3/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://img-global.cpcdn.com/003_recipes/3f7975f515414458/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://img-global.cpcdn.com/recipes/99c0f86c1b17d29f/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://1.bp.blogspot.com/-3IlmhKny1g0/Xz2kQ6nUbnI/AAAAAAAAdrA/5ff7rAnJw0kgV8UnBylIXbCikjbZAv5gQCNcBGAsYHQ/s2048/P_20200820_035450-01.jpeg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #36 from https://img-global.cpcdn.com/003_recipes/d6159ad387630e39/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #37 from https://img-global.cpcdn.com/recipes/c88f8db78f95d4fc/680x482cq70/oseng-oseng-tahu-tempe-foto-resep-utama.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #38 from https://www.masakapahariini.com/wp-content/uploads/2018/04/resep_oseng_tempe_MAHI-780x440.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from http://resepkoki.id/wp-content/uploads/2020/03/Resep-Oseng-Tempe-Cabe-Ijo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://sweetrip.id/wp-content/uploads/2022/07/oseng-tempe-pete-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://i.ytimg.com/vi/J48xFquvFl8/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://2.bp.blogspot.com/-uxTMBXlHhEs/WbtAzeMC-NI/AAAAAAAAFqg/U9ZUMF0eR3sUZ_lHV_8koFTMoh-qsc-hwCLcBGAs/w1200-h630-p-k-no-nu/Oseng%2BTempe%2BBaru.png
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://resepkoki.id/wp-content/uploads/2020/01/Resep-Oseng-Tahu-Tempe.jpg
# ...
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://3.bp.blogspot.com/--t-nf-UrDpw/U1tg-kjE65I/AAAAAAAALGg/OoNOI_IJQFE/s1600/IMG_6099.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://bonenenbiet.nl/wp-content/uploads/2020/03/Canva-Tempe-Goreng-Javanese-Vegetarian-Dish-of-Marinated-Fried-Tempeh-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://asset.kompas.com/crops/iEJb6R_R0VbEDp59hCH4DzgvxxE=/0x41:1000x708/750x500/data/photo/2020/04/01/5e841eccea33c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.idntimes.com/content-images/post/20190806/64914423-350270569014027-721314326503957408-n-0c35c6bb6f210d4ab6736d3d270ef463.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://www.roshvisual.com/wp-content/uploads/2014/11/Tempe-Goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://1.bp.blogspot.com/-EGOtAj2mtV8/WM1f8npj1JI/AAAAAAAAPKE/OdNAP4jTRXAXvff47pOmVoc3ZUcqrjJuACLcB/s1600/tempe-goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://img-global.cpcdn.com/recipes/de464ab6d0b1a78b/1502x1064cq70/tempe-goreng-tepung-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://awsimages.detik.net.id/community/media/visual/2018/09/09/162753b1-ffa8-4a88-9793-7c4b4ba3497e.jpeg?w=1242
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://i.pinimg.com/originals/76/40/e8/7640e89c46c20ea95225433cc17d49e7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://www.masakapahariini.com/wp-content/uploads/2022/09/resep-tempe-goreng-tepung-pedas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://4.bp.blogspot.com/-EP63zWegqW0/W_QjEH5FukI/AAAAAAABBBI/xlXXsfQgvqE8XfxJ6Gfv3fGZZPD6ehxrQCLcBGAs/s1600/Resepi%2BTempe%2BGoreng%2BBerlada.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://pisangsusu.com/wp-content/uploads/367-tempe-goreng-af.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://1.bp.blogspot.com/-k3uL-XP2o2k/UIQLE0osWSI/AAAAAAAAAWI/oi_zYPKuCuc/s1600/240320121407.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://i0.wp.com/www.emorygamelan.org/wp-content/uploads/2017/12/tempe-goreng.jpg?fit=825%2C550&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://img-global.cpcdn.com/recipes/9f46031ec828a908/1502x1064cq70/tempe-mendoan-garing-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://img-global.cpcdn.com/recipes/fbf5813b276dbe8e/1502x1064cq70/tempe-goreng-tepung-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://4.bp.blogspot.com/-L4E9qPIk8h4/UFlT5VZLAaI/AAAAAAAAAD0/ro3WhvsTjBI/s1600/tempe-goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://img-global.cpcdn.com/recipes/dad640d9bbf9c944/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://3.bp.blogspot.com/-Ri-hquIOFyo/T_59R16rVwI/AAAAAAAAAIU/RlLbb88Zk_M/s1600/DSC01235%255B1%255D.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.langsungenak.com/wp-content/uploads/2018/05/TEMPE-GORENG-KRIUK-LANGSUNGENAK.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://img-global.cpcdn.com/recipes/85dd46b4f7fadd0d/1502x1064cq70/tempe-goreng-tepung-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://www.mynewshub.tv/wp-content/uploads/2018/03/tempe1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://3.bp.blogspot.com/_2EJgUeGE54M/TSlPeluUucI/AAAAAAAAA9c/afwb-YPAZGg/s1600/Tempe+Goreng2.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://3.bp.blogspot.com/-gAplOLEB6Pc/VDrdPTVJ4PI/AAAAAAAAKfY/XgH-HJX6lv4/s1600/tempe%2Bgoreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://img-global.cpcdn.com/003_recipes/57435d6204fd5a7b/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://img-global.cpcdn.com/recipes/0495043592350655/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://img-global.cpcdn.com/recipes/5383ed7a1fb0315e/1502x1064cq70/tahu-tempe-goreng-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from http://keeprecipes.com/sites/keeprecipes/files/imagecache/recipe_large/resep_tempe_goreng_tepung.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #36 from https://4.bp.blogspot.com/-5gSVh_Z7QiM/TwMEO8jPdGI/AAAAAAAAACA/ZNeuGTxoBBs/s1600/tempe-goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://www.ajinomoto.com.my/sites/default/files/content/recipe-attach/2021-03/Fried-Tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://cdn.tasteatlas.com/images/dishes/27e10ff1d6934441a32903cb8047573f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://s3.bukalapak.com/img/344939055/w-1000/Sambal_Goreng_Tempe.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #40 from https://www.cookmeindonesian.com/wp-content/uploads/2020/09/tempe-goreng4-1140x1489.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #41 from http://4.bp.blogspot.com/-6hXyMsI8e2w/U1nUOkdmYCI/AAAAAAAAAt4/D2AqnICMRpI/s1600/Tempe-Goreng-Tepung.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #42 from https://3.bp.blogspot.com/-gCPY7G_D9Z8/TvMhpK0nzZI/AAAAAAAAAtI/NtClaI62PKw/s1600/Tempe+Goreng+Manis.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from http://1.bp.blogspot.com/-lfXpAE55zos/TyfUQH1yZ8I/AAAAAAAAGgI/XDwfFu2LVKE/s1600/aa2.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #44 from https://i.pinimg.com/originals/cb/b4/7b/cbb47b8bf1e69d24d4888a5b0360b0cc.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #45 from https://3.bp.blogspot.com/-OLOZJkPYlTg/U64dCK5tXCI/AAAAAAAADqQ/YVzT7jXdPhQ/s1600/IMG_1523.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://cdn1-production-images-kly.akamaized.net/cNSQqwjbvocsgS7C9h7Uic9Uig8=/958x0:3209x3000/640x853/filters:quality(75):strip_icc():format(jpeg)/kly-media-production/medias/2734642/original/063217000_1550735158-2019-02-20.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #47 from https://3.bp.blogspot.com/-lbk3EXNnEUs/VCTsQiMRSRI/AAAAAAAAATA/_g7pMK67ldk/s1600/tempe%2Bgurih.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #48 from http://thumbs.dreamstime.com/z/tempe-goreng-fried-tempeh-indonesian-vegetarian-food-soybean-product-48687238.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://cdn.statically.io/img/www.bidadari.my/wp-content/uploads/tempe-goreng.jpg
# [!] Issue getting: https://cdn.statically.io/img/www.bidadari.my/wp-content/uploads/tempe-goreng.jpg
# [!] Error:: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# [%] Downloading Image #49 from https://minyakgorengsunco.com/wp-content/uploads/2020/08/tempe-goreng-tepung.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 49 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\tempe mentah
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://doktersehat.com/wp-content/uploads/2018/09/tempe-mentah-doktersehat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://markaindo.com/wp-content/uploads/2021/06/shutterstock_1791237866.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://static.vecteezy.com/system/resources/previews/021/165/369/large_2x/tempe-mentah-raw-tempeh-uncooked-soybean-cake-from-indonesia-in-a-plastic-on-white-background-photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://awsimages.detik.net.id/community/media/visual/2020/06/09/tempe-3.jpeg?w=700&amp;q=90
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://s1.bukalapak.com/img/18484547901/w-1000/TEMPE_MENTAH.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-S-SrPSgQ6ac/WI38CNVPejI/AAAAAAAAABk/6CEg76d2cVg_OBQkeoGH26VwLuQAJn_8QCLcB/s1600/Indonesian%2BTempeh%2BRecipes.gif
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://awsimages.detik.net.id/community/media/visual/2020/06/09/tempe.jpeg?w=700&amp;q=90
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://image.makewebeasy.net/makeweb/0/aDHlzCExY/DefaultData/289A745B_9252_4EDF_AED5_F2AA6F8A2A43.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://static.wixstatic.com/media/33345e_93eb6d5b46b048e1915a1bfaac627dde~mv2.jpg/v1/fill/w_1000,h_488,al_c,q_90,usm_0.66_1.00_0.01/33345e_93eb6d5b46b048e1915a1bfaac627dde~mv2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://awsimages.detik.net.id/community/media/visual/2020/06/09/tempe-4.jpeg?w=724
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://www.maggi.id/sites/default/files/inline-images/shutterstock_1723571002.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://cdn-brilio-net.akamaized.net/news/2020/08/12/189993/1287446-cara-membuat-tempe-mentah.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://cdn-brilio-net.akamaized.net/news/2020/08/12/189993/750xauto-cara-membuat-tempe-mentah-enak-sederhana-dan-mudah-dibuat-200812a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://3.bp.blogspot.com/-nculYZz6NuY/VV7yNRLiptI/AAAAAAAAAJs/8tU0vI5C4Go/s1600/tempe2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://cdn.idntimes.com/content-images/community/2019/06/29090861-184775835643629-6011550662037340160-n-1-e6963f9a763c011c1d9d4bb13233d279.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://www.shutterstock.com/shutterstock/photos/2037503906/display_1500/stock-photo-raw-tempeh-or-tempe-mentah-bulat-tempeh-slices-in-wooden-plate-raw-soybean-seeds-in-a-brown-2037503906.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://cdn-brilio-net.akamaized.net/news/2020/08/12/189993/1287447-cara-membuat-tempe-mentah.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://awsimages.detik.net.id/community/media/visual/2018/05/04/b2460c78-cdda-418a-98d1-1587acd80a6b.jpeg?w=700&amp;q=90
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://dikemas.com/uploads/2019/04/tempe-mentah-360x203.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://mediaproxy.salon.com/width/1200/https://media.salon.com/2020/01/tempeh-table.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://cf.shopee.co.id/file/da8a01c1d7a3dc4a91640336df6a8063_tn
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://3.bp.blogspot.com/-0HWxyN1oRzU/VbFcJOwD4rI/AAAAAAAAAHA/aX95yK5RtHM/s1600/DSC03151.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://cdn.medcom.id/dynamic/content/2015/06/26/140772/Bw1R2i4ppb.jpg?w=1024
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://image.slidesharecdn.com/1-161206094305/85/jual-tempe-mentah-tempe-mentah-online-suplier-tempe-mentah-1-320.jpg?cb=1481017432
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://images.tokopedia.net/img/cache/500-square/VqbcmM/2021/7/25/3659aedd-acf6-4c0d-8b35-3e664e00e90d.png?ect=4g
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://img-global.cpcdn.com/recipes/13aa5cf3a0369337/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://media.suara.com/pictures/970x544/2021/01/27/93120-tempe-dan-tahu-goreng.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://images.tokopedia.net/img/cache/500-square/product-1/2017/7/21/8135412/8135412_4e27dcbd-d431-489c-9a13-283670e91664_1200_830.jpg?ect=4g
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://seru.co.id/wp-content/uploads/2022/02/Tempe-mentah-aneka-rasa-inovasi-perajin-tempe-Sanan-Kota-Malang-1024x683.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://s0.bukalapak.com/img/588233451/w-1000/Resep-Tempe-Mendoan.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://www.astronauts.id/blog/wp-content/uploads/2022/12/Penjelasan-Perbedaan-Kandungan-Gizi-Pada-Tahu-dan-Tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://ecs7.tokopedia.net/img/cache/200-square/product-1/2019/12/2/80540977/80540977_752895d0-51b4-4582-9cb5-0a74de0d33a6_1024_1024
# [!] Issue getting: https://ecs7.tokopedia.net/img/cache/200-square/product-1/2019/12/2/80540977/80540977_752895d0-51b4-4582-9cb5-0a74de0d33a6_1024_1024
# [!] Error:: The read operation timed out
# [%] Downloading Image #32 from https://png.pngtree.com/png-clipart/20211024/original/pngtree-tempe-illustration-png-fried-framented-soybean-png-image_6862680.png
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://cf.shopee.co.id/file/c93776f7dd77396045920651d33179f8
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://indolaras.com/wp-content/uploads/2018/09/BEKU0001-75NT.jpg
# [!] Issue getting: https://indolaras.com/wp-content/uploads/2018/09/BEKU0001-75NT.jpg
# [!] Error:: Remote end closed connection without response
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #34 from https://www.healthdigest.com/img/gallery/the-real-health-benefits-of-tempeh-explained/l-intro-1620221457.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from http://1.bp.blogspot.com/-4eurJ3xTqcs/V8QK31EfFZI/AAAAAAAAII8/gOl1uBHfk4ETlaQriW3bquHStujLenSgQCK4B/s1600/tempe.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://www.greencuisine.com/wp-content/uploads/2016/10/Tempeh_tempe-1030x773.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://i1.wp.com/3.bp.blogspot.com/-aY2KJQ6h-Jw/T2E8GVGez_I/AAAAAAAAA0s/dGb0zkgXVRE/s1600/IMG_0482.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://png.pngtree.com/png-vector/20210720/ourlarge/pngtree-tempe-panjang-illustrations-png-image-png-image_3614583.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://ecs7.tokopedia.net/img/cache/700/product-1/2020/6/9/53610163/53610163_9cf3f7ac-85a8-4cee-a09a-dcbf5eeac7e6_550_550
# [!] Issue getting: https://ecs7.tokopedia.net/img/cache/700/product-1/2020/6/9/53610163/53610163_9cf3f7ac-85a8-4cee-a09a-dcbf5eeac7e6_550_550
# [!] Error:: The read operation timed out
# [%] Downloading Image #39 from https://img.freepik.com/premium-vector/tempe-mentah_596819-290.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 39 images.
# [%] Downloading Images to c:\Users\ACER\final_project_ai_engineer_sa\test_dataset_tempe\tempeh
#
#
# [!!]Indexing page: 1
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 0 images.

# %%
import os
import shutil

def merge_folders_into_one_class(root_dir, output_dir):
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # List all subdirectories in the root directory
    subdirs = os.listdir(root_dir)

    # Copy files from all subdirectories to the output directory and rename them
    count = 1
    for subdir in subdirs:
        subdir_path = os.path.join(root_dir, subdir)
        if os.path.isdir(subdir_path):
            for file in os.listdir(subdir_path):
                src_path = os.path.join(subdir_path, file)
                dst_name = f"{count}.jpg"  # Change the extension according to your file type
                dst_path = os.path.join(output_dir, dst_name)
                shutil.copyfile(src_path, dst_path)
                count += 1


merge_folders_into_one_class(root_dir='dataset_tempe', output_dir='dataset/tempe')
merge_folders_into_one_class(root_dir='dataset_bukan_tempe', output_dir='dataset/bukan_tempe')

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms

class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.n_classes = len(self.classes)
        self.class_to_idx = {class_name: idx for idx, class_name in enumerate(self.classes)}
        self.file_paths = self._get_file_paths()

    def _get_file_paths(self):
        file_paths = []
        for class_name in self.classes:
            class_dir = os.path.join(self.root_dir, class_name)
            for file_name in os.listdir(class_dir):
                file_paths.append(os.path.join(class_dir, file_name))
        return file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        img_path = self.file_paths[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.class_to_idx[os.path.basename(os.path.dirname(img_path))]

        if self.transform:
            image = self.transform(image)

        return image, label

# Example usage:
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = CustomDataset(root_dir='dataset', transform=transform)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define a function to display a sample from the dataset
def show_sample(dataset, index):
    # Retrieve the sample from the dataset
    image, label = dataset[index]

    # Convert the PyTorch tensor image to a NumPy array and transpose the dimensions
    image = np.transpose(image.numpy(), (1, 2, 0))

    # Display the image
    plt.imshow(image)
    plt.title(f'Class: {dataset.classes[label]}')
    plt.axis('off')
    plt.show()

# Example usage:
# Define the index of the sample you want to visualize
sample_index = 0

# Display the sample
show_sample(dataset, sample_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 23
#      20 sample_index = 0
#      22 # Display the sample
# ---> 23 show_sample(dataset, sample_index)
#
# NameError: name 'dataset' is not defined

# %%
from torch.utils.data import random_split

# Define the sizes of training, validation, and test sets (in percentages)
train_size = 0.7
val_size = 0.15
test_size = 0.15

# Calculate the sizes of each split
total_size = len(dataset)
train_size = int(train_size * total_size)
val_size = int(val_size * total_size)
test_size = total_size - train_size - val_size

# Use random_split to split the dataset
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))
# Example usage:
print(f"Train set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Test set size: {len(test_dataset)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 test_size = 0.15
#       8 # Calculate the sizes of each split
# ----> 9 total_size = len(dataset)
#      10 train_size = int(train_size * total_size)
#      11 val_size = int(val_size * total_size)
#
# NameError: name 'dataset' is not defined

# %%
from numpy import clip, array
from matplotlib import pyplot as plt
from torch import Tensor

def imshow(inp: Tensor) -> None:
    """Imshow for Tensor."""
    inp = inp.cpu().numpy()
    inp = inp.transpose((1, 2, 0))
    mean = array([0.485, 0.456, 0.406])
    std = array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = clip(inp, 0, 1)
    plt.imshow(inp)
    plt.show()

# %%
"""
A training framework for classification tasks.
"""

from copy import deepcopy
from typing import List, Tuple
from os.path import join
from os import getcwd

from matplotlib.pyplot import subplots, show
from numpy import sum
from torch import argmax, device, cuda, save, load
from torch.nn import Module
from torch.nn.functional import softmax
from torch.nn.modules.loss import _Loss
from torch.optim import Optimizer
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm



class ClassificationModelTrainer:

    def __init__(self,
                 model: Module,
                 training_set: Dataset,
                 validation_set: Dataset,
                 batch_size: int,
                 minimising_criterion: _Loss,
                 optimiser: Optimizer) -> None:
        """
        Initialise a classification model training module.

        :param model: The model to train.
        :param training_set: The set of training data.
        :param validation_set: The set of validation data.
        :param batch_size: The batch size for training.
        :param minimising_criterion: The loss function.
        :param optimiser: The algorithm to perform minimisation task.
        """
        self._device = device("cuda:0" if cuda.is_available() else "cpu")
        self._model = model.to(self._device)
        self._train_loader = DataLoader(dataset=training_set, batch_size=batch_size, shuffle=True)
        self._validation_loader = DataLoader(dataset=validation_set, batch_size=batch_size, shuffle=True)
        self._minimising_criterion = minimising_criterion
        self._optimiser = optimiser
        self.training_loss = []
        self.validation_acc = []

    def get_model(self) -> Module:
        """
        Getter function for model.

        :return: Return the trained model.
        """
        return self._model

    def train_model(self, n_epochs) -> None:
        """
        Perform the model training.

        :param n_epochs: The number of training epochs to run.
        """
        # Setup the progress bar.
        pbar = tqdm(total=n_epochs * (len(self._train_loader) + len(self._validation_loader)))
        pbar.set_postfix({
            "Training Loss": "Not yet available" if len(self.training_loss) == 0 else self.training_loss[-1],
            "Validation Accuracy": "Not yet available" if len(self.validation_acc) == 0 else self.validation_acc[-1],
            "Epoch": 1
        })
        # Training through the epochs.
        for epoch in range(n_epochs):
            loss_sublist = []
            # Training Process
            for x, y in self._train_loader:
                x, y = x.to(self._device), y.to(self._device)
                self._model.train()
                z = self._model(x)
                loss = self._minimising_criterion(z, y)
                loss_sublist.append(loss.data.item())
                loss.backward()
                self._optimiser.step()
                self._optimiser.zero_grad()
                pbar.update()
            self.training_loss.append(sum(loss_sublist))
            # Validation Process
            correct = 0
            n_test = 0
            for x_test, y_test in self._validation_loader:
                x_test, y_test = x_test.to(self._device), y_test.to(self._device)
                self._model.eval()
                z = softmax(self._model(x_test), dim=1)
                y_hat = argmax(z.data, dim=1)
                correct += (y_hat == y_test).sum().item()
                n_test += y_hat.shape[0]
                pbar.update()
            accuracy = correct / n_test
            self.validation_acc.append(accuracy)
            pbar.set_postfix({
                "Training Loss": self.training_loss[-1],
                "Validation Accuracy": accuracy,
                "Epoch": epoch + 2
            })
        pbar.set_postfix({
            "Training Loss": self.training_loss[-1],
            "Validation Accuracy": self.validation_acc[-1],
            "Epoch": n_epochs
        })

    def plot_training_stat(self):
        """
        This function plots the training statistics the model trainer collected 
        throughout the training process. Namely, they are

        - Total training loss versus Iterations, and
        - Validation Accuracy versus Iterations.

        The two statistics are placed in the same plot, respectively in red and
        blue.
        """
        # Plot Total training loss versus Iterations
        fig, ax1 = subplots()
        color = 'tab:red'
        ax1.plot(self.training_loss, color=color)
        ax1.set_xlabel('Iterations', color="black")
        ax1.set_ylabel('Total Training Loss', color=color)
        ax1.set_ylim(bottom = 0)
        ax1.tick_params(axis='y', color=color)
        # Plot Validation Accuracy versus Iterations
        ax2 = ax1.twinx()
        color = 'tab:blue'
        ax2.set_ylabel('Validation Accuracy', color=color)
        ax2.plot(self.validation_acc, color=color)
        ax2.tick_params(axis='y', color=color)
        ax2.set_ylim(0, 1)
        fig.tight_layout()
        show()

    def test(self, testing_data: Dataset) -> float:
        """
        This function tests the model's performance on a given dataset.

        :param testing_data: The dataset to perform testing upon.
        :return: Model's accuracy on the given testing data.
        """
        _class = ["tempe", "not tempe"]
        j = 0
        total = 0
        print("Here are a list of inaccurately classified results:")
        for x, y in DataLoader(dataset=testing_data, batch_size=1, shuffle=True):
            x, y = x.to(self._device), y.to(self._device)
            predicted = argmax(softmax(self._model(x.to(self._device)), dim=1), dim=1)
            if predicted != y:
                j += 1
                print(f"Actual: {_class[y.item()]}\t\tPredicted: {_class[predicted.item()]}")
                imshow(x[0])
            total += 1
        return 100 - 100 * j / total

    def dump_to(self, file_name: str) -> None:
        """
        This function dumps the trained model. 

        :param file_name: The directory to save state files.
        """
        save_path = join(getcwd(), file_name)
        save({"model_params": self._model.state_dict(),
              "optimiser_stats": self._optimiser.state_dict(),
              "acc": self.validation_acc,
              "loss": self.training_loss
              }, save_path)
        
    def load_from(self, path: str) -> None:
        """
        This function loads the dumped file back to the training framework

        :param path: The path to the dumped file.
        """        
        state_dict = load(path, map_location=self._device)
        self._model.load_state_dict(state_dict["model_params"])
        self._optimiser.load_state_dict(state_dict["optimiser_stats"])
        self.validation_acc = state_dict["acc"]
        self.training_loss = state_dict["loss"]

# %%
imshow(train_dataset[10][0])

# %%
#from torchvision import models
from torchvision.models import resnet18, resnet50, ResNet50_Weights

model1 = resnet18(pretrained = True)
model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V2)

# Batch size: train set  
batch_size = 50

# Learning rate  
lr = 5e-3

# Number epochs 
n_epochs = 10
# resnet18 (fc): Linear(in_features=512, out_features=1000, bias=True)
# resnet50 (fc): Linear(in_features=2048, out_features=1000, bias=True)

# %%
from torch.nn import Linear

for param in model.parameters():
    param.requires_grad = False

# Next, we set `n_classes` to the number of classes we have. 
# Recall that we have two classes: "hotdog" and "not hotdog".
n_classes = dataset.n_classes

# Now that we have those parameters set, we can replace the output layer, 
# `model.fc` of the neural network, with a `nn.Linear` object to classify 
# `n_classes`'s different classes. For the first parameter, known as **in_features**, 
# we input 512 because the second last hidden layer of the neural network 
# has 512 neurons.
model.fc = Linear(2048, n_classes)

# %%
from torch.nn import CrossEntropyLoss

criterion = CrossEntropyLoss()

# %%
from torch.optim import Adam

optimizer = Adam(model.parameters(), lr = lr)

# %%
trainer = ClassificationModelTrainer(model,
                                     train_dataset,
                                     val_dataset,
                                     batch_size,
                                     criterion,
                                     optimizer,)

# %%
trainer.train_model(n_epochs)
# Out:
# 100%|██████████| 120/120 [15:53<00:00,  7.94s/it, Training Loss=1.01, Validation Accuracy=0.82, Epoch=10]

# %%
trainer.plot_training_stat()
# Out:
#   0%|          | 0/24 [54:02<?, ?it/s, Training Loss=Not yet available, Validation Accuracy=Not yet available, Epoch=1]

# %%
accuracy = trainer.test(test_dataset)
print(accuracy)

# %%
print(f"The model reached an accuracy rate of {accuracy:.2f}% on images it has never seen before.")
# Out:
# The model reached an accuracy rate of 85.15% on images it has never seen before.

# %%
trainer.dump_to("saved_model.pth")

# %%
import torch
from torch.nn import Linear
from PIL import Image
import requests
from io import BytesIO
import torchvision.transforms as transforms
import torchvision.models as models

# Function to preprocess an image from a URL
def preprocess_image(url):
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    return transform(image)

# Load the saved model
model = models.resnet50(pretrained=False)
model.fc = Linear(2048, 2)
model.load_state_dict(torch.load("saved_model.pth")['model_params'])
model.eval()


# Function to perform inference using the loaded model
def perform_inference(model, image):
    with torch.no_grad():
        output = model(image.unsqueeze(0))
    probabilities = torch.softmax(output, dim=1)
    predicted_class = torch.argmax(probabilities).item()
    confidence = probabilities[0, predicted_class].item()
    return predicted_class, confidence

# URL of the image from the web
image_url = 'https://cdn1-production-images-kly.akamaized.net/uNkYubvtEPM3S8pki06u1jO50-A=/958x0:3209x3000/469x625/filters:quality(75):strip_icc():format(webp)/kly-media-production/medias/2734642/original/063217000_1550735158-2019-02-20.jpg'

# Preprocess the image
image = preprocess_image(image_url)

# Perform inference
predicted_class, confidence = perform_inference(model, image)

# Output the results
print(f"Predicted Class: {predicted_class}, Confidence: {confidence}")
# Out:
# Predicted Class: 1, Confidence: 0.94789057970047
